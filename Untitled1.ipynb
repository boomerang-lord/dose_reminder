# %%
objlist = []
str1 = " "
f = open("database.txt", "r")
for x in f.readlines():
    str1 = x
    objlist.append(x)
    #print(x)
str2 = str1.split("}")

# %%
for x in str2:
    print(x[141:-1])
# Out:
# 2023, 12, 10, 20, 46, 44, 297000
# 2023, 12, 11, 2, 31, 42, 819000
# 2023, 12, 11, 15, 39, 27, 119000
# 2023, 12, 12, 3, 3, 28, 161000
# 2023, 12, 12, 4, 17, 19, 746000
# 2023, 12, 12, 12, 37, 0, 202000
# 2023, 12, 12, 12, 37, 22, 955000
# 2023, 12, 12, 12, 48, 6, 197000
# 2023, 12, 12, 15, 7, 21, 933000
# 2023, 12, 13, 5, 36, 33, 12000
# 2023, 12, 13, 15, 21, 24, 276000
# 2023, 12, 14, 2, 3, 13, 451000
# 2023, 12, 16, 4, 24, 31, 715000
# 2023, 12, 16, 4, 24, 59, 58000
# 2023, 12, 16, 4, 27, 24, 156000
# 2023, 12, 16, 4, 56, 45, 592000
# 2023, 12, 16, 4, 57, 38, 103000
# 2023, 12, 16, 4, 57, 50, 482000
# 2023, 12, 16, 5, 9, 11, 544000
# 2023, 12, 17, 4, 54, 5, 212000
# 2023, 12, 17, 15, 54, 32, 972000
# 2023, 12, 17, 19, 24, 47, 29000
# 2023, 12, 17, 19, 30, 35, 102000
# 2023, 12, 17, 19, 31, 6, 546000
# 2023, 12, 17, 19, 32, 24, 696000
# 2023, 12, 17, 19, 32, 55, 488000
# 2023, 12, 17, 19, 35, 33, 530000
# 2023, 12, 17, 19, 35, 49, 190000
# 2023, 12, 17, 19, 39, 21, 957000
# ...

# %%
firstL = []
secondL = []
for x in str2:
    firstL.append(x[64:78])
    
for x in firstL:
    if(x not in secondL):
        secondL.append(x)

# %%
for x in firstL:
    print(x)
# Out:
# 97648162293556
# 97648162293556
# 97648162293556
# 97648162293556
# 97648121929076
# 97648121929076
# 97648121929076
# 97648121929076
# 97648162293556
# 97648162293556
# 97648162293556
# 97648162293556
# 97648162293556
# 97648162293556
# 97648162293556
# 97648162293556
# 97648162293556
# 97648162293556
# 97648162293556
# 97648162293556
# 97648162293556
# 97648121929076
# 97648121929076
# 97648121929076
# 97648121929076
# 97648121929076
# 97648121929076
# 97648121929076
# 97648121929076
# 97648121929076
# 97648162293556
# 97648162293556

# %%
print(secondL)
# Out:
# ['97648162293556', '97648121929076', '']

# %%
# Making the the list of tuples with individual Ids

thirdL = []
for x in range(len(secondL)):
    thirdL.append((secondL[x],[],0 ))
   
print(thirdL)
# Out:
# [('97648162293556', [], 0), ('97648121929076', [], 0), ('', [], 0)]

# %%
# adding all the time stamps

for x in (str2):
    for y in range(len(thirdL)):
        #print(y[0])
        #print(x[64:78])
        if(x[64:78]== thirdL[y][0]):
            print(x[141:-1])
            thirdL[y][1].append(x[141:-1])
            #print(thirdL[y][1])
            
            
#print(thirdL)
    
    #if(thirdL[x][0]  x[64:78]):
# ...

# %%
fourthL = []
for x in thirdL:
    #print(x[1])
    fourthL.append((x[0], [], 0))
    
print(thirdL)


for x in thirdL:
    tmpL = []
    for y in range(len(x[1])):
        tmp1 = x[1][y]
        tmp2 = tmp1.split(" ")
        for i in range(len(tmp2)):
            #print(tmp2[i][-1:])
            if( tmp2[i][-1:] == ","):
                tmp2[i] = tmp2[i][:-1]
        #print(tmp2)
        num = (60 * int(tmp2[3]) + int(tmp2[4]) + int(tmp2[5])/60 + int(tmp2[6])/3600)
        tmpL.append(tmp2)
        print(fourthL[y])
        #fourthL[x][1].append(num)
        #print(x[1][y])
        #print("\n")
# Out:
# [('97648162293556', ['2023, 12, 10, 20, 46, 44, 297000', '2023, 12, 11, 2, 31, 42, 819000', '2023, 12, 11, 15, 39, 27, 119000', '2023, 12, 12, 3, 3, 28, 161000', '2023, 12, 12, 15, 7, 21, 933000', '2023, 12, 13, 5, 36, 33, 12000', '2023, 12, 13, 15, 21, 24, 276000', '2023, 12, 14, 2, 3, 13, 451000', '2023, 12, 16, 4, 24, 31, 715000', '2023, 12, 16, 4, 24, 59, 58000', '2023, 12, 16, 4, 27, 24, 156000', '2023, 12, 16, 4, 56, 45, 592000', '2023, 12, 16, 4, 57, 38, 103000', '2023, 12, 16, 4, 57, 50, 482000', '2023, 12, 16, 5, 9, 11, 544000', '2023, 12, 17, 4, 54, 5, 212000', '2023, 12, 17, 15, 54, 32, 972000', '2023, 12, 18, 3, 22, 18, 32000', '2023, 12, 18, 15, 19, 31, 838000', '2023, 12, 10, 20, 46, 44, 297000', '2023, 12, 11, 2, 31, 42, 819000', '2023, 12, 11, 15, 39, 27, 119000', '2023, 12, 12, 3, 3, 28, 161000', '2023, 12, 12, 15, 7, 21, 933000', '2023, 12, 13, 5, 36, 33, 12000', '2023, 12, 13, 15, 21, 24, 276000', '2023, 12, 14, 2, 3, 13, 451000', '2023, 12, 16, 4, 24, 31, 715000',
# ...

# %%
x = "2023, 12, 10, 20, 46, 44, 297000".split(", ")
l1 = []
for inc in range(4):
    #print(int(x[3]))
    num = (60 * int(x[3]) + int(x[4]) + int(x[5])/60 + int(x[6])/3600)
    l1.append(num)
print(l1)
# Out:
# [1329.2333333333333, 1329.2333333333333, 1329.2333333333333, 1329.2333333333333]

# %%
dict1 = {3:([1,2,3,4],12)}
#print(dict1[3][0][2])

for key in dict1:
    print(dict1[key][0][3])
# Out:
# 4
