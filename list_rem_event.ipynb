# %%
import json
import matplotlib.pyplot as plt
import pymongo
from types import SimpleNamespace
from datetime import datetime
from datetime import datetime, timedelta
import getopt
import sys

data = {
        "pid" :   "thread_id",
        "devId": '1234',
        "ts":datetime.now() 
        }


# Remove the first argument( the filename)
all_args = sys.argv[1:]

try:


   # Gather the arguments
   # c - collection name       long
   # p - thread id             integer
   # d - device id             string

    opts, arg = getopt.getopt(all_args, 'c:p:d:')
   # Should have exactly four options
    if len(opts) != 1:
       print("Usage: python3   list_rem_event.py -c rem-event")
    else:
      #print('Inserting heartbeat data into mongodb')
      # Iterate over the options and values
        index = 0;
        collection = ""
        for opt, arg_val in opts:
          #print (arg_val)
            if index == 0:
                collection = (arg_val)
                print (collection)
        
            


    client  =   pymongo.MongoClient("mongodb://104.156.230.214:27017/", username='sarathkamal', password='@Panayara57',  authSource='admin')
    #print("Connected to MongoDB")
    mydb    =   client["rem-test"]
    mycol   =   mydb[collection]  

    print("Accesed collection")

      #x   =   mycol.insert_one(data)
      #if x.inserted_id:
       #     print("Inserted record")
    f = open("database.txt", "a")
      
    fileLines = []
    timeStamps = []
    for y   in  mycol.find():
        fileLines.append(str(y))
        #f.write(str(y))
        #print(y) 
    f.close()
    for x in fileLines:
        y = 6
        print(x[64:78])
        time = (x[141:-2])

        if( x[64:78] == "97648162293556"):

            time2 = time.split(",")
            tmp = float(time2[3]) + float(time2[4])/60 + float(time2[5])/(60* 60) + float(time2[6])/(60* 60 * 60)
        #print(time2[6])
            timeStamps.append(tmp)
        #print(time)
    
    for x in timeStamps:
        print(x)
        #o = 0
    #plt.boxplot(timeStamps)

# Add labels and title
    #plt.xlabel('Data')
   # plt.ylabel('Values')
    #plt.title('Box Plot of Data')

# Show the plot
    #plt.show()



    plt.hist(timeStamps, bins=30, color='skyblue', edgecolor='black')
 
    # Adding labels and title
    plt.xlabel('Values')
    plt.ylabel('Frequency')
    plt.title('Basic Histogram')
 
    # Display the plot
    plt.show()
      
except getopt.GetoptError:
    print("Usage: python3   list_rem_event.py -c rem-event")
    sys.exit(2)


   #To get collection name 
   #list the collections
   
   #for coll in mydb.list_collection_names():
   #        print(coll)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Usage: python3   list_rem_event.py -c rem-event
# Traceback (most recent call last):
#   File "/var/folders/_7/cpbpv1xx247_3xvcrmhyj4sm0000gn/T/ipykernel_54994/3984490222.py", line 28, in <module>
#     opts, arg = getopt.getopt(all_args, 'c:p:d:')
#   File "/Users/sarathkamalkavitha/opt/anaconda3/lib/python3.9/getopt.py", line 95, in getopt
#     opts, args = do_shorts(opts, args[0][1:], shortopts, args[1:])
#   File "/Users/sarathkamalkavitha/opt/anaconda3/lib/python3.9/getopt.py", line 195, in do_shorts
#     if short_has_arg(opt, shortopts):
#   File "/Users/sarathkamalkavitha/opt/anaconda3/lib/python3.9/getopt.py", line 211, in short_has_arg
#     raise GetoptError(_('option -%s not recognized') % opt, opt)
# getopt.GetoptError: option -f not recognized
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# ...
